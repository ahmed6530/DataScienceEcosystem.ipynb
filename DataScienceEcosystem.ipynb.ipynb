# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# Data Science Tools and Ecosystem

# %% [markdown]
# ![2-title.png](attachment:image.png)

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# ![3-intro.png](attachment:image.png)

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
#
# 1. Python: Many data scientists use Python because it's flexible and has lots of tools for things like math, making predictions, and showing data as graphs.
#
# 2. R: R is good for math and graphs too. It's especially liked by people who study statistics and analyze data.
#
# 3. SQL: SQL is important for working with databases. It helps data scientists find and change information in big sets of data.
#
# These are just a few languages that data scientists use. The one they pick depends on what they're doing with the data.

# %% [markdown]
# ![4-dslanguages.png](attachment:image.png)

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
# 1. NumPy
# 2. pandas
# 3. scikit-learn

# %% [markdown]
# ![5-dslibraries.png](attachment:image.png)

# %% [markdown]
# Data Science Tools

# %%
print("| Data Science Tools |")
print("|---------------------|")
print("| Jupyter Notebook   |")
print("| Anaconda           |")
print("| Visual Studio Code |")
# Out:
# | Data Science Tools |
# |---------------------|
# | Jupyter Notebook   |
# | Anaconda           |
# | Visual Studio Code |

# %% [markdown]
# ![6-dstools.png](attachment:image.png)

# %% [markdown]
# Below are a few examples of evaluating arithmetic expressions in Python

# %%
1 + 2
5 * 3
8 / 2
2 ** 4
(4 + 6) / 2
# Out:
# 5.0

# %% [markdown]
# ![7-introarithmetic.png](attachment:image.png)

# %% [markdown]
# This a simple arithmetic expression to mutiply then add integers

# %%
result = (3 * 4) + 5
print(result)
# Out:
# 17

# %% [markdown]
# ![8-multiplyandaddintegers.png](attachment:image.png)

# %% [markdown]
# This will convert 200 minutes to hours by diving by 60

# %%
minutes = 200
hours = minutes / 60
print(hours)
# Out:
# 3.3333333333333335

# %% [markdown]
# List popular languages for Data Science

# %%
Objectives = 'python,SQl,R,JAVA'
sets_objectives = set(Objectives)

# %% [markdown]
# ![10-objectives.png](attachment:image.png)

# %% [markdown]
# ## Author
#
# Malik Muhammad Ahmed

# %% [markdown]
# ![11-authordetails.png](attachment:image.png)
